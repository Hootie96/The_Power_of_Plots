# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = r"C:\Users\kaleb\The_Power_of_Plots\Data Files\Mouse_metadata.csv"
study_results_path = r"C:\Users\kaleb\The_Power_of_Plots\Data Files\Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
lab_data = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')

# Display the data table for preview
lab_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
lab_data['Mouse ID'].count()
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = lab_data[lab_data.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
duplicate_mouseID = duplicate_mice['Mouse ID'].unique()

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mouse_data = lab_data[lab_data.duplicated(['Mouse ID'])]
dup_mouse_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
lab_data_clean = lab_data.drop_duplicates(subset=['Mouse ID', 'Timepoint'])
lab_data_clean
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
df = lab_data_clean['Mouse ID'].count()

# %%
lab_data_clean.describe()
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1888.000000  1888.000000  1888.000000         1888.000000
# mean     12.792903    25.661547    19.597458           50.449276
# std       7.186737     3.926776    14.084762            8.904565
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.951421
# 75%      20.000000    29.000000    30.000000           56.324075
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1888.000000
# mean           1.023835
# std            1.138507
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
df = lab_data_clean

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
df_mean = lab_data_clean.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
df_median = lab_data_clean.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
df_std = lab_data_clean.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
df_var = lab_data_clean.groupby('Drug Regimen').var()['Tumor Volume (mm3)']

df_sem = lab_data_clean.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']
# mean, median, variance, standard deviation, and SEM of the tumor volume.
data_summary = {'Mean': df_mean, 'Median': df_median, 'Standard Deviation': df_std, 'Variance': df_var, 'Standard Message Error': df_sem}
df_table = pd.DataFrame(data=data_summary)
df_table.head()
# Out:
#                    Mean     Median  Standard Deviation   Variance  \
# Drug Regimen
# Capomulin     40.675741  41.557809            4.994774  24.947764
# Ceftamin      52.591172  51.776157            6.268188  39.290177
# Infubinol     52.884795  51.820584            6.567243  43.128684
# Ketapril      55.235638  53.698743            8.279709  68.553577
# Naftisol      54.331565  52.509285            8.134708  66.173479
#
#               Standard Message Error
# Drug Regimen
# Capomulin                   0.329346
# Ceftamin                    0.469821
# Infubinol                   0.492236
# Ketapril                    0.603860
# Naftisol                    0.596466

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single linelab_data_clean.groupby("Drug Regimen")
summary_table = lab_data_clean.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean","median","var","std","sem"]})
summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas
lab_data_clean['Drug Regimen'].value_counts().plot(kind='bar')
plt.xlabel("Drug Regimen")
plt.ylabel("Mice Treatment")
plt.show()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
#unique function to find the number of mice 
#count_cap = lab_data.loc[lab_data['Drug Regimen'] == 'Capomulin' ]
#count_ram = lab_data.loc[lab_data['Drug Regimen'] == 'Ramicane']
#count_ket = lab_data.loc[lab_data['Drug Regimen'] == 'Ketapril']
#count_naf = lab_data.loc[lab_data['Drug Regimen'] == 'Naftisol']
#count_zon = lab_data.loc[lab_data['Drug Regimen'] == 'Zoniferol']
#count_ste = lab_data.loc[lab_data['Drug Regimen'] == 'Stelasyn']
#count_pla = lab_data.loc[lab_data['Drug Regimen'] == 'Placebo']
#count_inf = lab_data.loc[lab_data['Drug Regimen'] == 'Infubinol']
#count_cef = lab_data.loc[lab_data['Drug Regimen'] == 'Ceftamin']
#count_pro = lab_data.loc[lab_data['Drug Regimen'] == 'Propriva']
#counts_mice = pd.DataFrame({'Capomulin': count_cap.nunique()['Mouse ID'],
#               'Ramicane': count_ram.nunique()['Mouse ID'],'Ketapril': count_ket.nunique()['Mouse ID'],
#               'Naftisol': count_naf.nunique()['Mouse ID'], 'Zoniferol': count_zon.nunique()['Mouse ID'],
#               'Stelasyn': count_ste.nunique()['Mouse ID'],'Placebo': count_pla.nunique()['Mouse ID'],
#               'Infubinol':count_inf.nunique()['Mouse ID'],'Ceftamin': count_cef.nunique()['Mouse ID'],
#               'Propriva': count_pro.nunique()['Mouse ID']}, index=['Drug Regimen'])
#counts_mice.plot.bar(label='Mice per Drug Regimen')
#plt.xlabel('Drug Regimen')
#plt.ylabel('Number of Mice')
regimen=lab_data["Drug Regimen"].unique()
df_numpy= lab_data["Drug Regimen"].to_numpy()
lab_data["Drug Regimen"].unique()
plt.bar(regimen,df_numpy)
plt.xticks(rotation="vertical")
plt.xlabel("Drug Regimen")
plt.ylabel("Count for each treatment")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-e23476fad656> in <module>
#      23 df_numpy= lab_data["Drug Regimen"].to_numpy()
#      24 lab_data["Drug Regimen"].unique()
# ---> 25 plt.bar(regimen,df_numpy)
#      26 plt.xticks(rotation="vertical")
#      27 plt.xlabel("Drug Regimen")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2405         x, height, width=0.8, bottom=None, *, align='center',
#    2406         data=None, **kwargs):
# -> 2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
#    2409         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
#count_female = lab_data.loc[lab_data['Drug Regimen'] == 'Female']
#count_male = lab_data.loc[lab_data['Drug Regimen'] == 'Male']
#gender = pd.DataFrame({'Female': count_female, 'Male': count_male}, index=['Sex'])
sex_dist=lab_data_clean.groupby("Sex")["Sex"].count()
chart=sex_dist.plot.pie(subplots=True,autopct="%1.1f%%")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(sex_dist,autopct="%1.1f%%",labels=["Female","Male"])
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
M=lab_data_clean.set_index("Drug Regimen")
#Capomulin
C=M.loc[["Capomulin"],["Tumor Volume (mm3)","Mouse ID","Timepoint"]]
Capomulin=C.query(f"Timepoint== 45")
qrtls = Capomulin['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lq = qrtls[0.25]
uq = qrtls[0.75]
iqr = uq-lq
print(f"The interquartile range for Capomulin is: {iqr}")
ld = lq - (1.5*iqr)
ud = uq + (1.5*iqr)
#Ramicane
R=M.loc[["Ramicane"],["Tumor Volume (mm3)","Mouse ID","Timepoint"]]
Ramicane=R.query(f"Timepoint== 45")
qrtls1 = Ramicane['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lq1 = qrtls1[0.25]
uq1 = qrtls1[0.75]
iqr1 = uq1-lq1
print(f"The interquartile range for Ramicane is: {iqr1}")
ld1 = lq1 - (1.5*iqr1)
ud1 = uq1 + (1.5*iqr1)
#Infubinol
I=M.loc[["Ramicane"],["Tumor Volume (mm3)","Mouse ID","Timepoint"]]
Infubinol=I.query(f"Timepoint== 45")
qrtls2 = Infubinol['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lq2= qrtls2[0.25]
uq2 = qrtls2[0.75]
iqr2 = uq2-lq2
print(f"The interquartile range for Infubinol is: {iqr2}")
ld2 = lq2 - (1.5*iqr2)
ud2 = uq2 + (1.5*iqr2)
#Ceftamin
Ce=M.loc[["Ramicane"],["Tumor Volume (mm3)","Mouse ID","Timepoint"]]
Ceftamin=Ce.query(f"Timepoint== 45")
qrtls3 = Ceftamin['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lq3= qrtls3[0.25]
uq3 = qrtls3[0.75]
iqr3 = uq3-lq3
print(f"The interquartile range for Ceftamin is: {iqr3}")
ld3 = lq3 - (1.5*iqr3)
ud3 = uq3 + (1.5*iqr3)

IQR=pd.DataFrame({
    "Capomulin":iqr,
    "Ramicane":iqr1,
    "Infubinol":iqr2,
    "Ceftamin":iqr3
},index=["IQR"])
IQR
# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
# The interquartile range for Capomulin is: 7.781863460000004
# The interquartile range for Ramicane is: 7.527130082499998
# The interquartile range for Infubinol is: 7.527130082499998
# The interquartile range for Ceftamin is: 7.527130082499998
#      Capomulin  Ramicane  Infubinol  Ceftamin
# IQR   7.781863   7.52713    7.52713   7.52713

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, (ax1,ax2,ax3,ax4) = plt.subplots(4,sharex=True)

ax1.boxplot(Capomulin['Tumor Volume (mm3)'])
ax1.set_ylabel('Capomulin')

ax2.boxplot(Ramicane['Tumor Volume (mm3)'])
ax2.set_ylabel('Ramicane')

ax3.boxplot(Infubinol['Tumor Volume (mm3)'])
ax3.set_ylabel('Infubinol')

ax4.boxplot(Ceftamin['Tumor Volume (mm3)'])
ax4.set_ylabel('Ceftamin')

fig1.suptitle('Final tumor volume for each regimen') 
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
P=M.loc[["Capomulin"],["Tumor Volume (mm3)","Mouse ID","Timepoint"]]
L=P.set_index("Mouse ID")
SM=L.loc["s185"]
plt.plot(SM["Timepoint"],SM["Tumor Volume (mm3)"],marker="o")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Mouse S185 treated with Capomulin")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
MW=M.loc[["Capomulin"],["Tumor Volume (mm3)","Weight (g)","Mouse ID"]]
A=pd.DataFrame(MW.groupby("Mouse ID",as_index=False)["Tumor Volume (mm3)"].mean())
B=pd.DataFrame(MW.groupby("Mouse ID",as_index=False)["Weight (g)"].mean())
C=pd.merge(A,B,on="Mouse ID")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-a3d71da4d937> in <module>
#       4 B=pd.DataFrame(MW.groupby("Mouse ID",as_index=False)["Weight (g)"].mean())
#       5 C=pd.merge(A,B,on="Mouse ID")
# ----> 6 MW.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = C["Weight (g)"]
y_values = C["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(18,36),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Avg Tumor Volume')
plt.title("Avg Tumor Volume vs Weight(g)")
R2="R^2="+str(round(rvalue,4))
plt.annotate(R2,(22,38),fontsize=15,color="red")
print(f"The correlation coefficient(R^2) is: {rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is: 0.8419363424694718
